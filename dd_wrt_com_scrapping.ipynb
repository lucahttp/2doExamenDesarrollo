# %% [markdown]
# <a href="https://colab.research.google.com/github/lukaneco/2doExamenDesarrollo/blob/master/dd_wrt_com_scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install urllib2
#!pip install beautifulsoup4
from bs4 import BeautifulSoup
#from beautifulsoup4 import BeautifulSoup
from urllib.request import urlopen
#import urllib2
import re

#html_page = urlopen("https://arstechnica.com")
#html_page = urlopen("https://www.supermercadosdia.com.ar/")
html_page = urlopen("https://dd-wrt.com/routerdb/de/routerResult.php?action=routerList")
#print(html_page.read().decode('utf-8'))
soup = BeautifulSoup(html_page)
"""
print(html_page.read().decode('utf-8'))
for link in soup.findAll('tr'):
  #<div class="product">
    #print(link.get('href'))
    #print(link)
    print(link.get('onclick'))
"""

gdp_table = soup.find("table", attrs={"class": "list"})
#print(gdp_table)


gdp_table_data = gdp_table.findAll("tr")  # contains 2 rows

#print(gdp_table_data)
# Get all the headings of Lists
headings = []
for td in gdp_table_data[0].findAll("th"):
    # remove any newlines and extra spaces from left and right
    headings.append(td.text.replace('\n', ' ').strip())

print(headings)





data = {}

t_headers = []
gdp_table_data = gdp_table.findAll("tr")  # contains 2 rows
for td in gdp_table_data[0].findAll("th"):
  # remove any newlines and extra spaces from left and right
  t_headers.append(td.text.replace('\n', ' ').strip())


table_data = []
for tr in gdp_table.findAll("tr"): # find all tr's from table's tbody
    t_row = {}
    # Each table row is stored in the form of
    # t_row = {'Rank': '', 'Country/Territory': '', 'GDP(US$million)': ''}

    # find all td's(3) in tr and zip it with t_header
    for td, th in zip(tr.findAll("td"), t_headers): 

      t_row[th] = td.text.replace('\n', ' ').strip()


      #print(t_row[th])

    #print(t_row)
    if(t_row != {}):


      actionclickwithid = tr.get('onclick')

      import re
      myid = re.findall(r'\d+', actionclickwithid)[0]

      #myid = actionclickwithid.replace("showDetails('", "").replace("')", "") # showDetails('394')

      #print(myid)

      t_row["id"] = myid

      table_data.append(t_row)
      #print(t_row)

    else:
      print("empty")
      

t_headers.append("id")

# Put the data for the table with his heading.

"""
for row in table_data:
    if row:
        #print(row["id"])
        #time.sleep(1)
        #html_page = urlopen("https://dd-wrt.com/routerdb/de/routerResult.php?action=routerList")
        #print(html_page.read().decode('utf-8'))
        #soup = BeautifulSoup(html_page)
"""     


#print(t_headers)
#print(table_data)


import csv

with open("test.csv", 'w') as out_file:
    # Each 3 table has headers as following
    headers = t_headers
    writer = csv.DictWriter(out_file, headers)
    # write the header
    writer.writeheader()
    for row in table_data:
        if row:
            writer.writerow(row)
# Out:
# ['Manufacturer', 'Model', 'Revision', 'Supported', 'Activation required']
# empty

# %%
#myid="402"


#print(getCssSelector("tr.info:nth-of-type(4) td[valign]"))

#router_cpu = tree.xpath('//*[@id="left"]/h1/span/span/text()')


# document.querySelector("#left > table > tbody > tr:nth-child(2) > td:nth-child(2)")

#router_ram = tree.xpath('//*[@id="left"]/table/tbody/tr[3]/td[1]/text()')

#router_flash = tree.xpath('//*[@id="left"]/table/tbody/tr[4]/td[1]/text()')




#router_additional_information = tree.xpath('//*[@id="left"]/table/tbody/tr[2]/td[3]/ul/text()')
#This will create a list of prices

#print(type(router_cpu))
#print('Name: ', router_name,router_cpu,router_ram,router_flash,router_additional_information)



def getDeviceInfo(myid):
  url =  "https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id="+myid+"&site=drupal"


  print(url)
  from lxml import html

  from urllib.request import urlopen as uReq

  uClient = uReq(url)
  page_html = uClient.read()
  uClient.close()

  #page = requests.get(url)

  #print(page_html)
  #tree = html.fromstring(page_html)

  #This will create a list of buyers:
  #router_name = tree.xpath('//*[@id="left"]/h1/span/span/text()')
  from termcolor import colored

  from bs4 import BeautifulSoup as Soup
  soup = Soup(page_html)

  def getCssSelector(theselector):
    #print(colored('hello', 'red'), )
    router_cpu = soup.select(theselector)
    #print(colored(router_cpu, 'green'))
    toreturn = ""
    links = []
    
    #if(len(router_cpu) > 0):
    #toreturn = router_cpu[0].getText().replace("\n", "")

    if(len(router_cpu) > 0):
      for ici in router_cpu:

        toreturn = toreturn + ici.getText().replace("\n", "")


        thelinks = ici.findAll('a', href=True)
        if(len(thelinks) > 0):
          for link in thelinks:
            #print(colored(link['href'], 'red'))
            links.append(link['href'])
            toreturn = toreturn + " - " + link['href']
          #print(colored(links, 'blue'))
          #toreturn = toreturn + " - " + str(links)
      return toreturn
    else:
      return "null"
      


  device_info = {}
  device_info["name"] = getCssSelector("h1 span span")
  device_info["cpu"] = getCssSelector("td[width='100']")
  device_info["ram"] = getCssSelector("tr:nth-of-type(3) td[valign]")
  device_info["flash"] = getCssSelector("tr:nth-of-type(4) td[valign]")
  device_info["additional_information"] = getCssSelector(".comments")
  print(colored(device_info, 'blue'))
  return device_info

getDeviceInfo("100")
# Out:
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=100&site=drupal
# {'name': 'Linksys WRT54G v6.0', 'cpu': 'BCM5352', 'ram': '8 MB', 'flash': '2 MB', 'additional_information': 'DD-WRT Wiki: Linksys WRT54G v5.0/v5.1/v6.0 - http://dd-wrt.com/wiki/index.php/Linksys_WRT54G_v5.0_%26_5.1_%26_6.0'}
# {'additional_information': 'DD-WRT Wiki: Linksys WRT54G v5.0/v5.1/v6.0 - http://dd-wrt.com/wiki/index.php/Linksys_WRT54G_v5.0_%26_5.1_%26_6.0',
#  'cpu': 'BCM5352',
#  'flash': '2 MB',
#  'name': 'Linksys WRT54G v6.0',
#  'ram': '8 MB'}

# %% [markdown]
# # all joine

# %%
#!pip install urllib2
#!pip install beautifulsoup4
from bs4 import BeautifulSoup
#from beautifulsoup4 import BeautifulSoup
from urllib.request import urlopen
#import urllib2
import re


#myid="402"


#print(getCssSelector("tr.info:nth-of-type(4) td[valign]"))

#router_cpu = tree.xpath('//*[@id="left"]/h1/span/span/text()')


# document.querySelector("#left > table > tbody > tr:nth-child(2) > td:nth-child(2)")

#router_ram = tree.xpath('//*[@id="left"]/table/tbody/tr[3]/td[1]/text()')

#router_flash = tree.xpath('//*[@id="left"]/table/tbody/tr[4]/td[1]/text()')




#router_additional_information = tree.xpath('//*[@id="left"]/table/tbody/tr[2]/td[3]/ul/text()')
#This will create a list of prices

#print(type(router_cpu))
#print('Name: ', router_name,router_cpu,router_ram,router_flash,router_additional_information)



def getDeviceInfo(myid):
  url =  "https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id="+myid+"&site=drupal"


  print(url)
  from lxml import html

  from urllib.request import urlopen as uReq

  uClient = uReq(url)
  page_html = uClient.read()
  uClient.close()

  #page = requests.get(url)

  #print(page_html)
  #tree = html.fromstring(page_html)

  #This will create a list of buyers:
  #router_name = tree.xpath('//*[@id="left"]/h1/span/span/text()')
  from termcolor import colored

  from bs4 import BeautifulSoup as Soup
  soup = Soup(page_html)

  def getCssSelector(theselector):
    #print(colored('hello', 'red'), )
    router_cpu = soup.select(theselector)
    #print(colored(router_cpu, 'green'))
    toreturn = ""
    links = []
    
    #if(len(router_cpu) > 0):
    #toreturn = router_cpu[0].getText().replace("\n", "")

    if(len(router_cpu) > 0):
      for ici in router_cpu:

        toreturn = toreturn + ici.getText().replace("\n", "")


        thelinks = ici.findAll('a', href=True)
        if(len(thelinks) > 0):
          for link in thelinks:
            #print(colored(link['href'], 'red'))
            links.append(link['href'])
            toreturn = toreturn + " - " + link['href']
          #print(colored(links, 'blue'))
          #toreturn = toreturn + " - " + str(links)
      return toreturn
    else:
      return "null"
      


  device_info = {}
  device_info["name"] = getCssSelector("h1 span span")
  device_info["cpu"] = getCssSelector("td[width='100']")
  device_info["ram"] = getCssSelector("tr:nth-of-type(3) td[valign]")
  device_info["flash"] = getCssSelector("tr:nth-of-type(4) td[valign]")
  device_info["additional_information"] = getCssSelector(".comments")
  print(colored(device_info, 'blue'))
  return device_info

#getDeviceInfo("100")

#html_page = urlopen("https://arstechnica.com")
#html_page = urlopen("https://www.supermercadosdia.com.ar/")
html_page = urlopen("https://dd-wrt.com/routerdb/de/routerResult.php?action=routerList")
#print(html_page.read().decode('utf-8'))
soup = BeautifulSoup(html_page)
"""
print(html_page.read().decode('utf-8'))
for link in soup.findAll('tr'):
  #<div class="product">
    #print(link.get('href'))
    #print(link)
    print(link.get('onclick'))
"""

gdp_table = soup.find("table", attrs={"class": "list"})
#print(gdp_table)


gdp_table_data = gdp_table.findAll("tr")  # contains 2 rows

#print(gdp_table_data)
# Get all the headings of Lists
headings = []
for td in gdp_table_data[0].findAll("th"):
    # remove any newlines and extra spaces from left and right
    headings.append(td.text.replace('\n', ' ').strip())

print(headings)





data = {}

t_headers = []
gdp_table_data = gdp_table.findAll("tr")  # contains 2 rows
for td in gdp_table_data[0].findAll("th"):
  # remove any newlines and extra spaces from left and right
  t_headers.append(td.text.replace('\n', ' ').strip())


table_data = []

import time
for tr in gdp_table.findAll("tr"): # find all tr's from table's tbody
    t_row = {}
    # Each table row is stored in the form of
    # t_row = {'Rank': '', 'Country/Territory': '', 'GDP(US$million)': ''}

    # find all td's(3) in tr and zip it with t_header
    for td, th in zip(tr.findAll("td"), t_headers): 

      t_row[th] = td.text.replace('\n', ' ').strip()


      #print(t_row[th])

    #print(t_row)
    if(t_row != {}):


      actionclickwithid = tr.get('onclick')

      import re
      myid = re.findall(r'\d+', actionclickwithid)[0]

      #myid = actionclickwithid.replace("showDetails('", "").replace("')", "") # showDetails('394')

      #print(myid)

      t_row["id"] = myid


      device_info = getDeviceInfo(myid)
      time.sleep(1)
      t_row["device_info"] = device_info

      table_data.append(t_row)
      #print(t_row)

    else:
      print("empty")
      

t_headers.append("id")

# Put the data for the table with his heading.

"""
for row in table_data:
    if row:
        #print(row["id"])
        #time.sleep(1)
        #html_page = urlopen("https://dd-wrt.com/routerdb/de/routerResult.php?action=routerList")
        #print(html_page.read().decode('utf-8'))
        #soup = BeautifulSoup(html_page)
"""     


#print(t_headers)
#print(table_data)


import csv

with open("test.csv", 'w') as out_file:
    # Each 3 table has headers as following
    headers = t_headers
    writer = csv.DictWriter(out_file, headers)
    # write the header
    writer.writeheader()
    for row in table_data:
        if row:
            writer.writerow(row)
# Out:
# ['Manufacturer', 'Model', 'Revision', 'Supported', 'Activation required']
# empty
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=886&site=drupal
# {'name': '8devices Lima - (requires activation)', 'cpu': 'QCA4531', 'ram': '64 MB', 'flash': '32 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=887&site=drupal
# {'name': '8devices Rambutan - (requires activation)', 'cpu': 'QCA9557', 'ram': '128 MB', 'flash': '128 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=385&site=drupal
# {'name': 'Abocom WAP2102 - (requires activation)', 'cpu': 'AR2317', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'Same Hardware as : PlanexGW-MF54G2DD-WRT Forum: Flashing commands - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=411384#411384'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=1&site=drupal
# {'name': 'Accton MR3201A - (requires activation)', 'cpu': 'Atheros AR531X', 'ram': '16 MB', 'flash': '8 MB', 'additional_information': 'DD-WRT Wiki: Accton Software FlashingDD-WRT Wiki: Reflash Stock Firmware - http://www.dd-wrt.com/wiki/index.php/Accton_Software_Flashing - https://wiki.dd-wrt.com/wiki/index.php/Accton_Software_Flashing#Reflashing_Accton_original_firmware'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=2&site=drupal
# {'name': 'Accton MR3202a - (requires activation)', 'cpu': 'Atheros', 'ram': '0 MB', 'flash': '0 MB', 'additional_information': 'DD-WRT Wiki: Accton Software FlashingDD-WRT Wiki: Reflash Stock Firmware - http://www.dd-wrt.com/wiki/index.php/Accton_Software_Flashing - https://wiki.dd-wrt.com/wiki/index.php/Accton_Software_Flashing#Reflashing_Accton_original_firmware'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=394&site=drupal
# {'name': 'Aceex NR22/Y  ', 'cpu': 'RT3052F', 'ram': '32 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Forum: Flashing instructionsDD-WRT Forum: Reflash stock firmware - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=364500#364500 - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=364724#364724'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=324&site=drupal
# {'name': 'Actiontec MI424WR A, B', 'cpu': 'IXP425', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': "OEM'd to Verizon, FIOS port will not work!DD-WRT Wiki: MI424WRDD-WRT Forum: Revert stock firmware - http://dd-wrt.com/wiki/index.php/MI424WR - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=631396#631396"}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=402&site=drupal
# {'name': 'Actiontec MI424WR C', 'cpu': 'IXP425', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': "OEM'd to Verizon, FIOS port will not work! DD-WRT Wiki: MI424WRDD-WRT Forum: Revert stock firmware - http://dd-wrt.com/wiki/index.php/MI424WR - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=631396#631396"}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=375&site=drupal
# {'name': 'Actiontec MI424WR D', 'cpu': 'IXP425', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': "OEM'd to Verizon, FIOS port will not work! DD-WRT Wiki: MI424WRDD-WRT Forum: Revert stock firmware - http://dd-wrt.com/wiki/index.php/MI424WR - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=631396#631396"}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=3&site=drupal
# {'name': 'ADI Engineering Pronghorn Metro SBC - (requires activation)', 'cpu': '?', 'ram': '64 MB', 'flash': '16 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=199&site=drupal
# {'name': 'ADI Engineering Pronghorn SBC 210 - (requires activation)', 'cpu': 'IXP420', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=4&site=drupal
# {'name': 'Airlink 101 AR335W -', 'cpu': 'Atheros 2317', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'Same Hardware as DIR-300DD-WRT Wiki: Flashing instructions - https://wiki.dd-wrt.com/wiki/index.php/DIR300#Initial_flashing_instruction'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=5&site=drupal
# {'name': 'Airlink 101 AR430W V1', 'cpu': 'Atheros 2318', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'Same hardware as DIR-300DD-WRT Forum: Airlink AR430w flashing instructions - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=128891#128891'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=334&site=drupal
# {'name': 'Airlink 101 AR670W ?', 'cpu': 'RT2880 +RT2820 ', 'ram': '32 MB', 'flash': '4 MB', 'additional_information': 'Initial installation via webflashDD-WRT Forum: Revert stock firmware - http://dd-wrt.com/phpBB2/viewtopic.php?p=359906&sid=ef6c2f755bd4675d7c8244bd8cf25719#359906'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=347&site=drupal
# {'name': 'Airlink 101 AR690W ?', 'cpu': 'RT2880F', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'Initial installation via webDD-WRT Forum: Restore stock firmware - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=501591#501591'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=359&site=drupal
# {'name': 'Airlive/Ovislink Airmax 5 - (requires activation)', 'cpu': 'AR2312', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=200&site=drupal
# {'name': 'Airlive/Ovislink WHA-5500CPE - (requires activation)', 'cpu': 'AR2312', 'ram': '32 MB', 'flash': '4 MB', 'additional_information': 'Initial installation via original Web-Interface'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=201&site=drupal
# {'name': 'Airlive/Ovislink WHA-5500CPE-NT - (requires activation)', 'cpu': 'AR2312', 'ram': '32 MB', 'flash': '4 MB', 'additional_information': 'Initial installation via original Web-Interface'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=6&site=drupal
# {'name': 'Airlive/Ovislink WLA-5000ap - (requires activation)', 'cpu': 'AR2312', 'ram': '32 MB', 'flash': '4 MB', 'additional_information': 'Extern. How to install dd-wrt - http://fs.airlive.com/airlive_fileserver/uploads/FAQ/HOW_TO_INSTALL_DD_WRT_to_the_AirLive_WLA_5000AP.pdf'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=202&site=drupal
# {'name': 'Airlive/Ovislink WLA-9000ap - (requires activation)', 'cpu': 'AR5312', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': '\rThe firmware provided in original-to-dd-wrt.bin does not contain all features. \rUpgrade to WLA9000AP-firmware.bin after initial flashing.'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=580&site=drupal
# {'name': 'Alfa Networks AIP-W411 ?', 'cpu': 'AR7240', 'ram': '32 MB', 'flash': '4 MB', 'additional_information': 'Rebranded TL-WR741NDv1'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=586&site=drupal
# {'name': 'Alfa Networks AIP-W502U -', 'cpu': 'AR9130', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=376&site=drupal
# {'name': 'Alfa Networks AP048 / SoLo48 ? (requires activation)', 'cpu': 'AR5312', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': 'DD-WRT Forum: Flashing instructions - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=444804#444804'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=766&site=drupal
# {'name': 'Alfa Networks AP120C -', 'cpu': 'AR9340', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=583&site=drupal
# {'name': 'Allnet ALL0258 - (requires activation)', 'cpu': 'AR2313', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': 'EOC-5610 cloneDD-WRT Wiki: Install Micro-Redboot 1stDD-WRT FTP: Redboot-Collection - http://dd-wrt.com/wiki/index.php/Micro_Redboot - ftp://ftp.dd-wrt.com/others/redboot_collection/'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=587&site=drupal
# {'name': 'Allnet ALL02762 -', 'cpu': 'BCM5354', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'Shipped with DD-WRTExtern: Benutzerhandbuch - https://files.elv.com/service/manuals_hw/86038_ALL02762_UM.pdf'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=7&site=drupal
# {'name': 'Allnet All0277 -', 'cpu': 'Broadcom4702', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'Same hardware as wrt54g v1DD-WRT Wiki: InstructionsDD-WRT Wiki: TFTP-FlashingDD-WRT Downloads: DD-WRT v24 SP1 VINT - http://dd-wrt.com/wiki/index.php/Linksys_WRT54G_v1.0_%26_1.1 - http://dd-wrt.com/wiki/index.php/TFTP_flash - ftp://ftp.dd-wrt.com/v24-sp1/Consumer/Broadcom%20Generic/vintage/'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=212&site=drupal
# {'name': 'Allnet All391AP - (requires activation)', 'cpu': 'IXP425', 'ram': '64 MB', 'flash': '16 MB', 'additional_information': 'Requires Gateworks Avila Build'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=213&site=drupal
# {'name': 'Allnet ALL392BR - (requires activation)', 'cpu': 'IXP425', 'ram': '64 MB', 'flash': '16 MB', 'additional_information': 'Requires Gateworks Avila Build'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=214&site=drupal
# {'name': 'Allnet ALL392MAP - (requires activation)', 'cpu': 'IXP425', 'ram': '64 MB', 'flash': '16 MB', 'additional_information': 'Requires Gateworks Avila Build'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=215&site=drupal
# {'name': 'Allnet ALL392MRAP - (requires activation)', 'cpu': 'IXP425', 'ram': '64 MB', 'flash': '16 MB', 'additional_information': 'Requires Gateworks Avila Build'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=489&site=drupal
# {'name': 'Anaptyx AWR-100 - (requires activation)', 'cpu': 'AR710', 'ram': '64 MB', 'flash': '12 MB', 'additional_information': 'Clone of RouterStation'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=486&site=drupal
# {'name': 'Anaptyx ID-2 - (requires activation)', 'cpu': 'AR710', 'ram': '64 MB', 'flash': '16 MB', 'additional_information': 'Clone of RouterStation'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=487&site=drupal
# {'name': 'Anaptyx OD-2 - (requires activation)', 'cpu': 'AR710', 'ram': '64 MB', 'flash': '16 MB', 'additional_information': 'Clone of RouterStation'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=488&site=drupal
# {'name': 'Anaptyx OMW - (requires activation)', 'cpu': 'AR710', 'ram': '64 MB', 'flash': '16 MB', 'additional_information': 'Clone of RouterStation'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=11&site=drupal
# {'name': 'Askey RT2100W -', 'cpu': 'Broadcom?', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'Airgo must be replaced!!!Initial flashing via TFTP! - http://dd-wrt.com/wiki/index.php/TFTP_flash'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=8&site=drupal
# {'name': 'Askey RT210W -', 'cpu': 'Broadcom4710', 'ram': '16 MB', 'flash': '2 MB', 'additional_information': 'Same hardware as Siemens Gigaset SE505 v1DD-WRT Downloads: DD-WRT v24 SP1 VINTInitial flashing via TFTP! - ftp://ftp.dd-wrt.com/v24-sp1/Consumer/Broadcom%20Generic/vintage/ - http://dd-wrt.com/wiki/index.php/TFTP_flash'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=12&site=drupal
# {'name': 'Askey RT2206D -', 'cpu': 'Broadcom?', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'Initial flashing via TFTP! - http://dd-wrt.com/wiki/index.php/TFTP_flash'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=9&site=drupal
# {'name': 'Askey RT220XD -', 'cpu': 'Broadcom?', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'Initial flashing via TFTP! - http://dd-wrt.com/wiki/index.php/TFTP_flash'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=10&site=drupal
# {'name': 'Askey RT480W -', 'cpu': 'Broadcom?', 'ram': '16 MB', 'flash': '2 MB', 'additional_information': 'Same hardware as Siemens Gigaset SE505 v2Initial flashing via TFTP! - http://dd-wrt.com/wiki/index.php/TFTP_flash'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=767&site=drupal
# {'name': 'ASRock G10 (AC2600) -', 'cpu': 'IPQ8064', 'ram': '512 MB', 'flash': '128 MB', 'additional_information': 'Initial flashing via Web-Interface'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=771&site=drupal
# {'name': 'Asus RT-AC1200G+ -', 'cpu': 'BCM47189', 'ram': '128 MB', 'flash': '16 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=889&site=drupal
# {'name': 'Asus RT-AC1900P -', 'cpu': 'BCM4709A0', 'ram': '256 MB', 'flash': '256 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=772&site=drupal
# {'name': 'Asus RT-AC3100 -', 'cpu': 'BCM47094', 'ram': '512 MB', 'flash': '128 MB', 'additional_information': 'DD-WRT Forum: Flashing instructions - https://forum.dd-wrt.com/phpBB2/viewtopic.php?p=1002698#1002698'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=773&site=drupal
# {'name': 'Asus RT-AC3200 -', 'cpu': 'BCM4709A0', 'ram': '256 MB', 'flash': '128 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=774&site=drupal
# {'name': 'Asus RT-AC5300 -', 'cpu': 'BCM47094', 'ram': '256 MB', 'flash': '128 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=720&site=drupal
# {'name': 'Asus RT-AC56U (AC1200) -', 'cpu': 'BCM', 'ram': '256 MB', 'flash': '128 MB', 'additional_information': 'DD-WRT Wiki: Flashing instructionsDD-WRT Wiki: Reflash stock firmware - https://wiki.dd-wrt.com/wiki/index.php/Asus_RT-AC56U#Flashing_DD-WRT_Firmware - https://wiki.dd-wrt.com/wiki/index.php/Asus_RT-AC56U#OEM_Firmware_Installation'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=584&site=drupal
# {'name': 'Asus RT-AC66U (AC1750) -', 'cpu': 'BCM4706', 'ram': '256 MB', 'flash': '128 MB', 'additional_information': 'DD-WRT Wiki: Flashing instructions - https://wiki.dd-wrt.com/wiki/index.php/Asus_RT-AC66U#Installation_instructions'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=768&site=drupal
# {'name': 'Asus RT-AC68P (AC1900) -', 'cpu': 'BCM4709', 'ram': '256 MB', 'flash': '128 MB', 'additional_information': 'Uses RT-AC68U FirmwareDD-WRT Wiki: Flashing instructionsDD-WRT Wiki: Reflash stock firmware - https://wiki.dd-wrt.com/wiki/index.php/Asus_RT-AC68U#Firmware_Install_Procedure - https://wiki.dd-wrt.com/wiki/index.php/Asus_RT-AC68U#Original_Firmware_Install_Procedure'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=719&site=drupal
# {'name': 'Asus RT-AC68U (AC1900) -', 'cpu': 'BCM4708A0', 'ram': '256 MB', 'flash': '128 MB', 'additional_information': 'DD-WRT Wiki: Flashing instructionsDD-WRT Wiki: Reflash stock firmware - https://wiki.dd-wrt.com/wiki/index.php/Asus_RT-AC68U#Firmware_Install_Procedure - https://wiki.dd-wrt.com/wiki/index.php/Asus_RT-AC68U#Original_Firmware_Install_Procedure'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=769&site=drupal
# {'name': 'Asus RT-AC87U (AC2400) -', 'cpu': 'BCM4709A0', 'ram': '128 MB', 'flash': '128 MB', 'additional_information': 'Initial installation via Web-Interface'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=770&site=drupal
# {'name': 'Asus RT-AC88U (AC3100) -', 'cpu': 'BCM47094', 'ram': '512 MB', 'flash': '128 MB', 'additional_information': 'Ininial installation via Web-Interface'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=465&site=drupal
# {'name': 'Asus RT-G32 -', 'cpu': 'Atheros 2317', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: Asus RT-G32 - https://wiki.dd-wrt.com/wiki/index.php/ASUS_RT-G32'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=517&site=drupal
# {'name': 'Asus RT-G32 B1', 'cpu': 'RT3052', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=466&site=drupal
# {'name': 'Asus RT-N10 A', 'cpu': 'Broadcom5356', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Forum: ASUS RT-N10 Support-DiscussionDD-WRT Wiki: K2.6 Build variations - http://www.dd-wrt.com/phpBB2/viewtopic.php?t=64725&postdays=0&postorder=asc&start=0 - https://wiki.dd-wrt.com/wiki/index.php/What_is_DD-WRT%3F#K2.6_Build_Features'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=775&site=drupal
# {'name': 'Asus RT-N10 C1', 'cpu': 'RT3050F', 'ram': '32 MB', 'flash': '4 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=547&site=drupal
# {'name': 'Asus RT-N10 / RT-N10+ B1', 'cpu': 'RT3050F', 'ram': '32 MB', 'flash': '4 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=776&site=drupal
# {'name': 'Asus RT-N10+ D1', 'cpu': 'BCM5356', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Forum: Installation instructionsDD-WRT Wiki: K2.6 Build variations - https://forum.dd-wrt.com/phpBB2/viewtopic.php?p=959086#959086 - https://wiki.dd-wrt.com/wiki/index.php/What_is_DD-WRT%3F#K2.6_Build_Features'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=550&site=drupal
# {'name': 'Asus RT-N10U -', 'cpu': 'BCM5356', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: Installation instructionsDD-WRT Wiki: K2.6 Build variations - https://wiki.dd-wrt.com/wiki/index.php/Asus_RT-N10U#Installation_Instructions - https://wiki.dd-wrt.com/wiki/index.php/What_is_DD-WRT%3F#K2.6_Build_Features'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=585&site=drupal
# {'name': 'Asus RT-N10U_BLACK -', 'cpu': 'BCM5357', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': 'DD-WRT Wiki: Installation instructionsDD-WRT Wiki: K2.6 Build variations - https://wiki.dd-wrt.com/wiki/index.php/Asus_RT-N10U#Installation_Instructions - https://wiki.dd-wrt.com/wiki/index.php/What_is_DD-WRT%3F#K2.6_Build_Features'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=467&site=drupal
# {'name': 'Asus RT-N12 A', 'cpu': 'Broadcom4716', 'ram': '32 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: Installation instructionsDD-WRT Wiki: K2.6 Build variations - https://wiki.dd-wrt.com/wiki/index.php/Asus_RT-N12#A1.2C_B1.2C_C1_Installation - https://wiki.dd-wrt.com/wiki/index.php/What_is_DD-WRT%3F#K2.6_Build_Features'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=548&site=drupal
# {'name': 'Asus RT-N12 B', 'cpu': 'Broadcom BCM5357', 'ram': '32 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: Installation instructionsDD-WRT Wiki: K2.6 Build variations - https://wiki.dd-wrt.com/wiki/index.php/Asus_RT-N12#A1.2C_B1.2C_C1_Installation - https://wiki.dd-wrt.com/wiki/index.php/What_is_DD-WRT%3F#K2.6_Build_Features'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=573&site=drupal
# {'name': 'Asus RT-N12 C', 'cpu': 'Broadcom BCM5357', 'ram': '32 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: Installation instructionsDD-WRT Wiki: K2.6 Build variations - https://wiki.dd-wrt.com/wiki/index.php/Asus_RT-N12#A1.2C_B1.2C_C1_Installation - https://wiki.dd-wrt.com/wiki/index.php/What_is_DD-WRT%3F#K2.6_Build_Features'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=936&site=drupal
# {'name': 'Asus RT-N12 D', 'cpu': 'BCM5357', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': 'DD-WRT Wiki: Installation instructionsDD-WRT Wiki: K2.6 Build variations - https://wiki.dd-wrt.com/wiki/index.php/Asus_RT-N12#RT-N12D1_Installation_.28updated_March_21_2018.29 - https://wiki.dd-wrt.com/wiki/index.php/What_is_DD-WRT%3F#K2.6_Build_Features'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=472&site=drupal
# {'name': 'Asus RT-N13U A', 'cpu': 'Ralink3052', 'ram': '32 MB', 'flash': '4 MB', 'additional_information': 'Initial installation via Web-InterfaceDD-WRT Forum: Automount ext3 script inc fat/fat32 - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=454647#454647'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=549&site=drupal
# {'name': 'Asus RT-N13U B1', 'cpu': 'RT3052', 'ram': '64 MB', 'flash': '8 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=777&site=drupal
# {'name': 'Asus RT-N14U C1', 'cpu': 'MT7620N', 'ram': '64 MB', 'flash': '16 MB', 'additional_information': '                TBD                '}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=469&site=drupal
# {'name': 'Asus RT-N15 -', 'cpu': 'RT2880F', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: Asus RT-N15 - http://www.dd-wrt.com/wiki/index.php/Asus_RT-N15'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=778&site=drupal
# {'name': 'Asus RT-N15U -', 'cpu': 'BCM5357r2', 'ram': '64 MB', 'flash': '8 MB', 'additional_information': '                TBD                '}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=446&site=drupal
# {'name': 'Asus RT-N16 -', 'cpu': 'Broadcom4718A', 'ram': '128 MB', 'flash': '32 MB', 'additional_information': 'DD-WRT Wiki: Installation instructionsDD-WRT Wiki: K2.6 Build variations - https://wiki.dd-wrt.com/wiki/index.php/Asus_RT-N16#Install_DD-WRT_from_Factory_Firmware - https://wiki.dd-wrt.com/wiki/index.php/What_is_DD-WRT%3F#K2.6_Build_Features'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=721&site=drupal
# {'name': 'Asus RT-N18U -', 'cpu': 'BCM47081', 'ram': '256 MB', 'flash': '128 MB', 'additional_information': 'Initial flash via Web-Interface'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=578&site=drupal
# {'name': 'Asus RT-N53U -', 'cpu': 'BCM5358', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': '5 GHz not functional'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=577&site=drupal
# {'name': 'Asus RT-N66U -', 'cpu': 'BCM4706', 'ram': '256 MB', 'flash': '32 MB', 'additional_information': 'DD-WRT Wiki: Installation instructionsDD-WRT Wiki: Reflash stock firmware - https://wiki.dd-wrt.com/wiki/index.php/Asus_RT-N66U#Installation_Instructions - https://wiki.dd-wrt.com/wiki/index.php/Asus_RT-N66U#Revert_to_original_ASUS_firmware'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=13&site=drupal
# {'name': 'Asus WL-300G -', 'cpu': 'Broadcom4710', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'Initial flash via TFTPDD-WRT Downloads: DD-WRT v24 SP1 VINT - http://dd-wrt.com/wiki/index.php/TFTP_flash - ftp://ftp.dd-wrt.com/v24-sp1/Consumer/Broadcom%20Generic/vintage/'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=491&site=drupal
# {'name': 'Asus WL-330gE -', 'cpu': 'BCM5354 chip rev 2', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=14&site=drupal
# {'name': 'Asus WL-500b -', 'cpu': 'Broadcom4710', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: All Asus WL-500xx series routers - http://www.dd-wrt.com/wiki/index.php/All_Asus_WL-500xx_series_routers'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=15&site=drupal
# {'name': 'Asus WL-500g -', 'cpu': 'Broadcom4710', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: All Asus WL-500xx series routersDD-WRT Downloads: DD-WRT v24 SP1 VINT - http://www.dd-wrt.com/wiki/index.php/All_Asus_WL-500xx_series_routers - ftp://ftp.dd-wrt.com/v24-sp1/Consumer/Broadcom%20Generic/vintage/'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=16&site=drupal
# {'name': 'Asus WL-500g Deluxe -', 'cpu': 'Broadcom5365', 'ram': '32 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: All Asus WL-500xx series routersDD-WRT Wiki: Asus WL-500g Deluxe - http://www.dd-wrt.com/wiki/index.php/All_Asus_WL-500xx_series_routers - http://www.dd-wrt.com/wiki/index.php/Asus_WL-500g_Deluxe'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=509&site=drupal
# {'name': 'Asus WL-500gP v1', 'cpu': 'BCM4704', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=510&site=drupal
# {'name': 'Asus WL-500gP v2', 'cpu': 'BCM5354', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': 'DD-WRT Wiki: Asus WL-500g Premium V2 - https://wiki.dd-wrt.com/wiki/index.php/Asus_WL-500g_Premium_V2'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=19&site=drupal
# {'name': 'Asus WL-500W -', 'cpu': 'Broadcom4704', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': 'DD-WRT Wiki: Asus WL500W - http://dd-wrt.com/wiki/index.php/Asus_WL500W'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=20&site=drupal
# {'name': 'Asus WL-520G -', 'cpu': 'Broadcom5350', 'ram': '8 MB', 'flash': '2 MB', 'additional_information': 'DD-WRT Wiki: ASUS WL-520G - http://dd-wrt.com/wiki/index.php/Asus_WL520G'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=21&site=drupal
# {'name': 'Asus WL-520gC -', 'cpu': 'Broadcom5354', 'ram': '16 MB', 'flash': '2 MB', 'additional_information': 'DD-WRT Wiki: ASUS WL-520GC - http://dd-wrt.com/wiki/index.php/ASUS_WL-520GC'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=22&site=drupal
# {'name': 'Asus WL-520gU -', 'cpu': 'Broadcom5354', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: Asus WL-520GU - http://dd-wrt.com/wiki/index.php/Asus_WL-520GU'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=23&site=drupal
# {'name': 'Asus WL550GE -', 'cpu': 'Broadcom5352', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: AsusDD-WRT Wiki: All Asus WL-500xx series routers - http://dd-wrt.com/wiki/index.php/Asus - http://dd-wrt.com/wiki/index.php/All_Asus_WL-500xx_series_routers'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=348&site=drupal
# {'name': 'Belkin 7230-4 v6000tc', 'cpu': '?', 'ram': '0 MB', 'flash': '0 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=24&site=drupal
# {'name': 'Belkin F5D7130 v1xxx', 'cpu': 'Broadcom?', 'ram': '4 MB', 'flash': '2 MB', 'additional_information': 'Initial flash via TFTPDD-WRT Downloads: DD-WRT v24 SP1 VINT - https://wiki.dd-wrt.com/wiki/index.php/Tftp_flash - ftp://ftp.dd-wrt.com/v24-sp1/Consumer/Broadcom%20Generic/vintage/'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=25&site=drupal
# {'name': 'Belkin F5D7130 v2xxx', 'cpu': 'Broadcom4710', 'ram': '8 MB', 'flash': '2 MB', 'additional_information': 'Initial flash via TFTPDD-WRT Downloads: DD-WRT v24 SP1 VINT - https://wiki.dd-wrt.com/wiki/index.php/Tftp_flash - ftp://ftp.dd-wrt.com/v24-sp1/Consumer/Broadcom%20Generic/vintage/'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=26&site=drupal
# {'name': 'Belkin F5D7130-4 v1010', 'cpu': 'Broadcom', 'ram': '8 MB', 'flash': '2 MB', 'additional_information': 'Initial flash via TFTPDD-WRT Downloads: DD-WRT v24 SP1 VINT - https://wiki.dd-wrt.com/wiki/index.php/Tftp_flash - ftp://ftp.dd-wrt.com/v24-sp1/Consumer/Broadcom%20Generic/vintage/'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=27&site=drupal
# {'name': 'Belkin F5D7130-4 v1112', 'cpu': 'Broadcom4710', 'ram': '8 MB', 'flash': '2 MB', 'additional_information': 'Initial flash via TFTPDD-WRT Downloads: DD-WRT v24 SP1 VINT - https://wiki.dd-wrt.com/wiki/index.php/Tftp_flash - ftp://ftp.dd-wrt.com/v24-sp1/Consumer/Broadcom%20Generic/vintage/'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=417&site=drupal
# {'name': 'Belkin F5D7130uk v2115uk', 'cpu': 'Broadcom4710 rev0', 'ram': '8 MB', 'flash': '2 MB', 'additional_information': 'WARNING:Always use TFTP to flash this router! Upgrading dd-wrt from the web interface can lead to a bricked (nonfunctional) device! - http://dd-wrt.com/wiki/index.php/TFTP_flash'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=28&site=drupal
# {'name': 'Belkin F5D7130uk v3xxx', 'cpu': 'Broadcom4712', 'ram': '8 MB', 'flash': '2 MB', 'additional_information': 'Initial flash via TFTP - https://wiki.dd-wrt.com/wiki/index.php/Tftp_flash'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=30&site=drupal
# {'name': 'Belkin F5D7230-4 1000fr, v1444, v2000df', 'cpu': 'Broadcom4712', 'ram': '8 MB', 'flash': '2 MB', 'additional_information': 'Initial flash via TFTPDD-WRT Downloads: DD-WRT v24 SP1 VINT - https://wiki.dd-wrt.com/wiki/index.php/Tftp_flash - ftp://ftp.dd-wrt.com/v24-sp1/Consumer/Broadcom%20Generic/vintage/'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=29&site=drupal
# {'name': 'Belkin F5D7230-4 v1000, v1010, v1111, v1112, v1222de, v1223df, v122', 'cpu': 'Broadcom4710', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'Same hardware as Gigaset SE505 v1Initial flash via TFTPDD-WRT Downloads: DD-WRT v24 SP1 VINT - https://wiki.dd-wrt.com/wiki/index.php/Tftp_flash - ftp://ftp.dd-wrt.com/v24-sp1/Consumer/Broadcom%20Generic/vintage/'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=31&site=drupal
# {'name': 'Belkin F5D7230-4 v2xxx', 'cpu': 'Broadcom4712', 'ram': '8 MB', 'flash': '2 MB', 'additional_information': 'DD-WRT Wiki: Installation instructions - https://wiki.dd-wrt.com/wiki/index.php/Belkin_F5D7230-4_v2000%2Cv2000de_%2B_Belkin_F5D7231-4_v1102%2Cv1003ee%2C_and_v1103uk'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=32&site=drupal
# {'name': 'Belkin F5D7230-4 v3xxx', 'cpu': 'Broadcom?', 'ram': '8 MB', 'flash': '2 MB', 'additional_information': 'Initial flash via TFTP - https://wiki.dd-wrt.com/wiki/index.php/Tftp_flash'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=445&site=drupal
# {'name': 'Belkin F5D7230-4 v6000/v6002', 'cpu': '?', 'ram': '0 MB', 'flash': '0 MB', 'additional_information': 'DD-WRT Forum: Belkin F5D72304 v6000 - \\"http://www.dd-wrt.com/phpBB2/viewtopic.php?t=1327&highlight=belkin+f5d72304+v6000\\"'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=333&site=drupal
# {'name': 'Belkin F5D7230-4 v7000', 'cpu': '?', 'ram': '4 MB', 'flash': '1 MB', 'additional_information': 'To less flash memory to run dd-wrt'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=345&site=drupal
# {'name': 'Belkin F5D7230-4 v8000', 'cpu': '?', 'ram': '0 MB', 'flash': '1 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=336&site=drupal
# {'name': 'Belkin F5D7230-4 v9000', 'cpu': '?', 'ram': '0 MB', 'flash': '0 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=450&site=drupal
# {'name': 'Belkin F5D7230-4 vA000', 'cpu': 'AR2317-AC1A', 'ram': '8 MB', 'flash': '2 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=377&site=drupal
# {'name': 'Belkin F5D7231-4 v10xx', 'cpu': '?', 'ram': '8 MB', 'flash': '2 MB', 'additional_information': 'Initial flash via TFTP - https://wiki.dd-wrt.com/wiki/index.php/Tftp_flash'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=34&site=drupal
# {'name': 'Belkin F5D7231-4 v11xx', 'cpu': 'Broadcom4712', 'ram': '8 MB', 'flash': '2 MB', 'additional_information': 'Serial Flash - Device, use SF build'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=35&site=drupal
# {'name': 'Belkin F5D7231-4 v12xx', 'cpu': 'Broadcom5352', 'ram': '8 MB', 'flash': '2 MB', 'additional_information': 'Initial flash via TFTP - https://wiki.dd-wrt.com/wiki/index.php/Tftp_flash'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=36&site=drupal
# {'name': 'Belkin F5D7231-4 v20xx', 'cpu': 'Broadcom5352', 'ram': '8 MB', 'flash': '2 MB', 'additional_information': 'Initial flash via TFTP - https://wiki.dd-wrt.com/wiki/index.php/Tftp_flash'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=378&site=drupal
# {'name': 'Belkin F5D7231-4P v10xx', 'cpu': 'Broadcom4712', 'ram': '16 MB', 'flash': '2 MB', 'additional_information': 'Initial flash via TFTP - https://wiki.dd-wrt.com/wiki/index.php/Tftp_flash'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=37&site=drupal
# {'name': 'Belkin F5D7330 -', 'cpu': 'Broadcom', 'ram': '8 MB', 'flash': '2 MB', 'additional_information': 'Initial flash via TFTPDD-WRT Downloads: DD-WRT v24 SP1 VINT - https://wiki.dd-wrt.com/wiki/index.php/Tftp_flash - ftp://ftp.dd-wrt.com/v24-sp1/Consumer/Broadcom%20Generic/vintage/'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=38&site=drupal
# {'name': 'Belkin F5D8230-4 v10xx', 'cpu': 'Broadcom4704', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'Airgo Wireless NIC must be replaced with Broadcom or other compatible unit!Initial flash via TFTP - https://wiki.dd-wrt.com/wiki/index.php/Tftp_flash'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=368&site=drupal
# {'name': 'Belkin F5D8231-4 -', 'cpu': '?', 'ram': '0 MB', 'flash': '0 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=194&site=drupal
# {'name': 'Belkin F5D8232-4 1000, 1021uk', 'cpu': 'Atheros AR7141', 'ram': '18 MB', 'flash': '8 MB', 'additional_information': 'DD-WRT Forum: Belkin F5D8232-4 - http://www.dd-wrt.com/phpBB2/viewtopic.php?t=33382'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=507&site=drupal
# {'name': 'Belkin F5D8233-4 ?', 'cpu': '?', 'ram': '0 MB', 'flash': '2 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=888&site=drupal
# {'name': 'Belkin F5D8235-4 v20xx', 'cpu': 'AR7141', 'ram': '16 MB', 'flash': '8 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=351&site=drupal
# {'name': 'Belkin F5D8236-4 ?', 'cpu': '?', 'ram': '0 MB', 'flash': '2 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=350&site=drupal
# {'name': 'Belkin F5D8633-4 v1', 'cpu': '?', 'ram': '0 MB', 'flash': '0 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=444&site=drupal
# {'name': 'Belkin F6D4230-4 v1000', 'cpu': '?', 'ram': '0 MB', 'flash': '2 MB', 'additional_information': 'To less flash memory to run DD-WRT'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=588&site=drupal
# {'name': 'Belkin F7D3301 v1', 'cpu': 'BCM4718', 'ram': '64 MB', 'flash': '8 MB', 'additional_information': 'DD-WRT Forum: Flashing instructionsDD-WRT Wiki: K2.6 Build variations - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=492842#492842 - https://wiki.dd-wrt.com/wiki/index.php/What_is_DD-WRT%3F#K2.6_Build_Features'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=590&site=drupal
# {'name': 'Belkin F7D3302 v1', 'cpu': 'BCM4718', 'ram': '64 MB', 'flash': '8 MB', 'additional_information': 'DD-WRT Forum: Flashing instructionsDD-WRT Wiki: K2.6 Build variations - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=603693#603693 - https://wiki.dd-wrt.com/wiki/index.php/What_is_DD-WRT%3F#K2.6_Build_Features'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=592&site=drupal
# {'name': 'Belkin F7D4301 v1', 'cpu': 'BCM4718', 'ram': '64 MB', 'flash': '8 MB', 'additional_information': 'Initial flash via CFE Web ServerDD-WRT Wiki: K2.6 Build variations - https://forum.dd-wrt.com/phpBB2/viewtopic.php?t=78042 - https://wiki.dd-wrt.com/wiki/index.php/What_is_DD-WRT%3F#K2.6_Build_Features'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=594&site=drupal
# {'name': 'Belkin F7D4302 v1', 'cpu': 'BCM4718', 'ram': '64 MB', 'flash': '8 MB', 'additional_information': 'Initial flash via CFE Web ServerDD-WRT Wiki: K2.6 Build variations - https://forum.dd-wrt.com/phpBB2/viewtopic.php?t=78042 - https://wiki.dd-wrt.com/wiki/index.php/What_is_DD-WRT%3F#K2.6_Build_Features'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=589&site=drupal
# {'name': 'Belkin F7D7301 v1', 'cpu': 'BCM4718', 'ram': '64 MB', 'flash': '8 MB', 'additional_information': 'DD-WRT Forum: Flashing instructionsDD-WRT Wiki: K2.6 Build variations - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=492842#492842 - https://wiki.dd-wrt.com/wiki/index.php/What_is_DD-WRT%3F#K2.6_Build_Features'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=591&site=drupal
# {'name': 'Belkin F7D7302 v1', 'cpu': 'BCM4718', 'ram': '64 MB', 'flash': '8 MB', 'additional_information': 'DD-WRT Forum: Flashing instructionsDD-WRT Wiki: K2.6 Build variations - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=603693#603693 - https://wiki.dd-wrt.com/wiki/index.php/What_is_DD-WRT%3F#K2.6_Build_Features'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=593&site=drupal
# {'name': 'Belkin F7D8301 v1', 'cpu': 'BCM4718', 'ram': '64 MB', 'flash': '8 MB', 'additional_information': 'Initial flash via CFE Web ServerDD-WRT Wiki: K2.6 Build variations - https://forum.dd-wrt.com/phpBB2/viewtopic.php?t=78042 - https://wiki.dd-wrt.com/wiki/index.php/What_is_DD-WRT%3F#K2.6_Build_Features'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=595&site=drupal
# {'name': 'Belkin F7D8302 v1', 'cpu': 'BCM4718', 'ram': '64 MB', 'flash': '8 MB', 'additional_information': 'Initial flash via CFE Web ServerDD-WRT Wiki: K2.6 Build variations - https://forum.dd-wrt.com/phpBB2/viewtopic.php?t=78042 - https://wiki.dd-wrt.com/wiki/index.php/What_is_DD-WRT%3F#K2.6_Build_Features'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=360&site=drupal
# {'name': 'Bountiful BWRG1000 _ (requires activation)', 'cpu': '?', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'Same as BWRG500DD-WRT Wiki: BWRG500 - http://www.dd-wrt.com/wiki/index.php/Bountiful_BWRG500'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=404&site=drupal
# {'name': 'Bountiful BWRG500 - (requires activation)', 'cpu': '?', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: BWRG500 - http://www.dd-wrt.com/wiki/index.php/Bountiful_BWRG500'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=511&site=drupal
# {'name': 'Browan BW1251 -', 'cpu': 'IXP425', 'ram': '64 MB', 'flash': '16 MB', 'additional_information': 'Board donation needed for port! - http://www.dd-wrt.com/site/community/donations'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=779&site=drupal
# {'name': 'Buffalo BHR-4GRV -', 'cpu': 'AR7242', 'ram': '64 MB', 'flash': '32 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=39&site=drupal
# {'name': 'Buffalo WAPM-HP-AM54G54 -', 'cpu': 'Broadcom4704', 'ram': '64 MB', 'flash': '8 MB', 'additional_information': 'DD-WRT Wiki: Buffalo - http://dd-wrt.com/wiki/index.php/Buffalo'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=569&site=drupal
# {'name': 'Buffalo WBMR-HP-G300H  ', 'cpu': 'AR9', 'ram': '64 MB', 'flash': '32 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=40&site=drupal
# {'name': 'Buffalo WBR-G54 -', 'cpu': 'Broadcom4710', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: BuffaloMaybe needs VINT images! Check corerev! - http://dd-wrt.com/wiki/index.php/Buffalo - http://dd-wrt.com/wiki/index.php/What_is_DD-WRT%3F#Which_V24_build_do_I_flash_onto_my_Broadcom_router'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=41&site=drupal
# {'name': 'Buffalo WBR2-G54 -', 'cpu': 'Broadcom', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: Buffalo - http://dd-wrt.com/wiki/index.php/Buffalo'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=42&site=drupal
# {'name': 'Buffalo WBR2-G54S -', 'cpu': 'Broadcom4712', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: Buffalo - http://dd-wrt.com/wiki/index.php/Buffalo'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=596&site=drupal
# {'name': 'Buffalo WCR-GN -', 'cpu': 'RT3350F', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Forum: Serial-Console flashingDD-WRT Forum: Flashing instructions - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=660458#660458 - https://forum.dd-wrt.com/phpBB2/viewtopic.php?p=955142'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=782&site=drupal
# {'name': 'Buffalo WHR-1166D (AC1200) v1', 'cpu': 'MT7620A', 'ram': '128 MB', 'flash': '8 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=780&site=drupal
# {'name': 'Buffalo WHR-300HP2(D) v1', 'cpu': 'MT7620A', 'ram': '64 MB', 'flash': '8 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=781&site=drupal
# {'name': 'Buffalo WHR-600D v1', 'cpu': 'MT7620A', 'ram': '64 MB', 'flash': '8 MB', 'additional_information': 'DD-WRT Forum: Back to original firmware - https://forum.dd-wrt.com/phpBB2/viewtopic.php?t=264398&start=23'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=493&site=drupal
# {'name': 'Buffalo WHR-AMG54 _', 'cpu': 'Broadcom5352', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=44&site=drupal
# {'name': 'Buffalo WHR-G125 -', 'cpu': 'Broadcom5354', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: Buffalo - http://dd-wrt.com/wiki/index.php/Buffalo'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=218&site=drupal
# {'name': 'Buffalo WHR-G300N v1', 'cpu': 'RaLink', 'ram': '32 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: WHR-G300N - http://dd-wrt.com/wiki/index.php/WHR-G300N'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=453&site=drupal
# {'name': 'Buffalo WHR-G300N v2', 'cpu': 'Atheros7240', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': 'DD-WRT Wiki: WHR-G300N V2 - http://dd-wrt.com/wiki/index.php/WHR-G300N_V2'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=43&site=drupal
# {'name': 'Buffalo WHR-G54S -', 'cpu': 'Broadcom5352', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: BuffaloDD-WRT Wiki: Buffalo WHR-G54S and WHR-HP-G54 SD/MMC mod - http://dd-wrt.com/wiki/index.php/Buffalo - http://dd-wrt.com/wiki/index.php/Buffalo_WHR-G54S_and_WHR-HP-G54_SD/MMC_mod'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=45&site=drupal
# {'name': 'Buffalo WHR-HP-AG108 -', 'cpu': 'Atheros5312', 'ram': '32 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: Installation instructions - https://wiki.dd-wrt.com/wiki/index.php/WHR-HP-AG108'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=452&site=drupal
# {'name': 'Buffalo WHR-HP-G300N -', 'cpu': 'Atheros ar7240', 'ram': '32 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: Installation instructions - https://wiki.dd-wrt.com/wiki/index.php/WHR-HP-G300N'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=46&site=drupal
# {'name': 'Buffalo WHR-HP-G54 -', 'cpu': 'Broadcom5352', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: Buffalo WHR-HP-G54DD-WRT Wiki: Buffalo WHR-G54S and WHR-HP-G54 SD/MMC mod - https://wiki.dd-wrt.com/wiki/index.php/WHR-HP-G54 - http://dd-wrt.com/wiki/index.php/Buffalo_WHR-G54S_and_WHR-HP-G54_SD/MMC_mod'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=47&site=drupal
# {'name': 'Buffalo WHR-HP-G54-DD -', 'cpu': 'Broadcom5352', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: BuffaloDD-WRT Wiki: Buffalo WHR-G54S and WHR-HP-G54 SD/MMC mod - http://dd-wrt.com/wiki/index.php/Buffalo - http://dd-wrt.com/wiki/index.php/Buffalo_WHR-G54S_and_WHR-HP-G54_SD/MMC_mod'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=454&site=drupal
# {'name': 'Buffalo WHR-HP-GN -', 'cpu': 'Atheros ar7240', 'ram': '32 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: Buffalo - http://dd-wrt.com/wiki/index.php/Buffalo'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=597&site=drupal
# {'name': 'Buffalo  WHR3-AG54 -', 'cpu': 'BCM4704', 'ram': '64 MB', 'flash': '4 MB', 'additional_information': 'Use always TFTP for updates - http://dd-wrt.com/wiki/index.php/TFTP_flash'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=48&site=drupal
# {'name': 'Buffalo WLA-G54 -', 'cpu': 'Broadcom4702', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: Buffalo - http://dd-wrt.com/wiki/index.php/Buffalo'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=49&site=drupal
# {'name': 'Buffalo WLA-G54C -', 'cpu': 'Broadcom4702', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: Buffalo - http://dd-wrt.com/wiki/index.php/Buffalo'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=50&site=drupal
# {'name': 'Buffalo WLA2-G54C -', 'cpu': 'Broadcom4712', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: Buffalo - http://dd-wrt.com/wiki/index.php/Buffalo'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=51&site=drupal
# {'name': 'Buffalo WLA2-G54L -', 'cpu': 'Broadcom4702', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: Buffalo - http://dd-wrt.com/wiki/index.php/Buffalo'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=783&site=drupal
# {'name': 'Buffalo WLAE-AG-300N -', 'cpu': 'AR7240', 'ram': '32 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Forum: Back to original firmware - https://forum.dd-wrt.com/phpBB2/viewtopic.php?p=947235&sid=9516d8ab22bb35add8ffd2fe7a7add09'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=52&site=drupal
# {'name': 'Buffalo WLAH-G54 -', 'cpu': 'Broadcom4702', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: Buffalo - http://dd-wrt.com/wiki/index.php/Buffalo'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=784&site=drupal
# {'name': 'Buffalo WLI-H4-D1300 -', 'cpu': 'BCM4706', 'ram': '128 MB', 'flash': '128 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=53&site=drupal
# {'name': 'Buffalo WLI-TX1-G54 -', 'cpu': 'Broadcom5352', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: Buffalo - http://dd-wrt.com/wiki/index.php/Buffalo'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=54&site=drupal
# {'name': 'Buffalo WLI-TX4-G54HP -', 'cpu': 'Broadcom5352', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Wiki: Buffalo - http://dd-wrt.com/wiki/index.php/Buffalo'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=55&site=drupal
# ...
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=304&site=drupal
# {'name': 'Ubiquiti PowerStation5ext - (requires activation)', 'cpu': 'ARAR2313', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'Requires LiteStation5 firmwareDD-WRT Forum: FLASH or RECOVER UBIQUITI DEVICES to DD-WRT/AirOSOther downloads - http://www.dd-wrt.com/phpBB2/viewtopic.php?t=45474 - http://dd-wrt.com/site/support/other-downloads?path=others%2Feko%2FBrainSlayer-V24-preSP2%2F'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=461&site=drupal
# {'name': 'Ubiquiti Rocket M2 - (requires activation)', 'cpu': 'AR7420', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': 'DD-WRT Forum: FLASH or RECOVER UBIQUITI DEVICES to DD-WRT/AirOSOther downloads - http://www.dd-wrt.com/phpBB2/viewtopic.php?t=45474 - http://dd-wrt.com/site/support/other-downloads?path=others%2Feko%2FBrainSlayer-V24-preSP2%2F'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=750&site=drupal
# {'name': 'Ubiquiti Rocket M2 Titanium - (requires activation)', 'cpu': 'AR7370', 'ram': '128 MB', 'flash': '8 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=908&site=drupal
# {'name': 'Ubiquiti Rocket M2 Titanium XW - (requires activation)', 'cpu': '-', 'ram': '0 MB', 'flash': '0 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=910&site=drupal
# {'name': 'Ubiquiti Rocket M3 - (requires activation)', 'cpu': '-', 'ram': '0 MB', 'flash': '0 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=499&site=drupal
# {'name': 'Ubiquiti Rocket M365 - (requires activation)', 'cpu': '-', 'ram': '64 MB', 'flash': '8 MB', 'additional_information': 'DD-WRT Forum: FLASH or RECOVER UBIQUITI DEVICES to DD-WRT/AirOSOther downloads - http://www.dd-wrt.com/phpBB2/viewtopic.php?t=45474 - http://dd-wrt.com/site/support/other-downloads?path=others%2Feko%2FBrainSlayer-V24-preSP2%2F'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=462&site=drupal
# {'name': 'Ubiquiti Rocket M5 - (requires activation)', 'cpu': 'AR7420', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': 'DD-WRT Forum: FLASH or RECOVER UBIQUITI DEVICES to DD-WRT/AirOSOther downloads - http://www.dd-wrt.com/phpBB2/viewtopic.php?t=45474 - http://dd-wrt.com/site/support/other-downloads?path=others%2Feko%2FBrainSlayer-V24-preSP2%2F'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=751&site=drupal
# {'name': 'Ubiquiti Rocket M5 Titanium - (requires activation)', 'cpu': 'AR7370', 'ram': '128 MB', 'flash': '8 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=907&site=drupal
# {'name': 'Ubiquiti Rocket M5 Titanium XW - (requires activation)', 'cpu': '-', 'ram': '0 MB', 'flash': '0 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=555&site=drupal
# {'name': 'Ubiquiti Rocket M900 - (requires activation)', 'cpu': '-', 'ram': '64 MB', 'flash': '8 MB', 'additional_information': 'DD-WRT Forum: FLASH or RECOVER UBIQUITI DEVICES to DD-WRT/AirOSOther downloads - http://www.dd-wrt.com/phpBB2/viewtopic.php?t=45474 - http://dd-wrt.com/site/support/other-downloads?path=others%2Feko%2FBrainSlayer-V24-preSP2%2F'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=305&site=drupal
# {'name': 'Ubiquiti RouterStation - (requires activation)', 'cpu': 'AR7161', 'ram': '64 MB', 'flash': '16 MB', 'additional_information': 'DD-WRT Forum: FLASH or RECOVER UBIQUITI DEVICES to DD-WRT/AirOSOther downloads - http://www.dd-wrt.com/phpBB2/viewtopic.php?t=45474 - http://dd-wrt.com/site/support/other-downloads?path=others%2Feko%2FBrainSlayer-V24-preSP2%2F'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=398&site=drupal
# {'name': 'Ubiquiti RouterStation Pro   (requires activation)', 'cpu': 'AR7161', 'ram': '128 MB', 'flash': '16 MB', 'additional_information': 'DD-WRT Forum: FLASH or RECOVER UBIQUITI DEVICES to DD-WRT/AirOSOther downloads - http://www.dd-wrt.com/phpBB2/viewtopic.php?t=45474 - http://dd-wrt.com/site/support/other-downloads?path=others%2Feko%2FBrainSlayer-V24-preSP2%2F'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=570&site=drupal
# {'name': 'Ubiquiti Unifi AP - (requires activation)', 'cpu': 'AR7240', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': 'Other downloads - http://dd-wrt.com/site/support/other-downloads?path=others%2Feko%2FBrainSlayer-V24-preSP2%2F'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=943&site=drupal
# {'name': 'Ubiquiti Unifi AP v2 (requires activation)', 'cpu': 'AR7240', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=933&site=drupal
# {'name': 'Ubiquiti Unifi AP AC - (requires activation)', 'cpu': 'BCM4706', 'ram': '256 MB', 'flash': '16 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=934&site=drupal
# {'name': 'Ubiquiti Unifi AP AC Outdoor - (requires activation)', 'cpu': 'BCM4706', 'ram': '256 MB', 'flash': '16 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=941&site=drupal
# {'name': 'Ubiquiti Unifi AP LR - (requires activation)', 'cpu': 'AR7240', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=942&site=drupal
# {'name': 'Ubiquiti Unifi AP LR v2 (requires activation)', 'cpu': 'AR7240', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=932&site=drupal
# {'name': 'Ubiquiti Unifi AP Outdoor - (requires activation)', 'cpu': 'AR724x', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=498&site=drupal
# {'name': 'Ubiquiti WifiStation - (requires activation)', 'cpu': '?', 'ram': '0 MB', 'flash': '0 MB', 'additional_information': 'DD-WRT Forum: FLASH or RECOVER UBIQUITI DEVICES to DD-WRT/AirOS - http://www.dd-wrt.com/phpBB2/viewtopic.php?t=45474'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=909&site=drupal
# {'name': 'Ubiquiti WispStation M5 - (requires activation)', 'cpu': 'AR7240', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=306&site=drupal
# {'name': 'Ubiquiti WispStation5 - (requires activation)', 'cpu': 'AR5312', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Forum: FLASH or RECOVER UBIQUITI DEVICES to DD-WRT/AirOS - http://www.dd-wrt.com/phpBB2/viewtopic.php?t=45474'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=181&site=drupal
# {'name': 'US Robotics USR5430 Rev 1', 'cpu': 'Broadcom 4712', 'ram': '8 MB', 'flash': '2 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=182&site=drupal
# {'name': 'US Robotics USR5432 -', 'cpu': 'Broadcom 4712', 'ram': '8 MB', 'flash': '2 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=307&site=drupal
# {'name': 'US Robotics USR5441 -', 'cpu': '5350', 'ram': '8 MB', 'flash': '2 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=183&site=drupal
# {'name': 'US Robotics USR5451 -', 'cpu': 'Broadcom 5350', 'ram': '8 MB', 'flash': '2 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=184&site=drupal
# {'name': 'US Robotics USR5453 -', 'cpu': 'Atheros AR2313', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': 'Other downloads - http://dd-wrt.com/site/support/other-downloads?path=others%2Feko%2FBrainSlayer-V24-preSP2%2F'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=185&site=drupal
# {'name': 'US Robotics USR5461 -', 'cpu': 'Broadcom 5350', 'ram': '8 MB', 'flash': '2 MB', 'additional_information': 'DD-WRT Wiki: USR5461 - https://wiki.dd-wrt.com/wiki/index.php/USR5461'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=349&site=drupal
# {'name': 'US Robotics USR5464 ?', 'cpu': '?', 'ram': '0 MB', 'flash': '0 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=186&site=drupal
# {'name': 'US Robotics USR805430 -', 'cpu': 'Broadcom 4712', 'ram': '8 MB', 'flash': '2 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=703&site=drupal
# {'name': 'US Robotics USR8200 -', 'cpu': 'IXP422', 'ram': '64 MB', 'flash': '16 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=308&site=drupal
# {'name': 'Valemount Lucaya M1020 - (requires activation)', 'cpu': 'ADM5120', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'Compex WP54 v24 preSP2 buildMyloader must be installed'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=309&site=drupal
# {'name': 'Valemount Lucaya M1023 - (requires activation)', 'cpu': 'ADM5120', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'Compex WP54 v24 preSP2 buildMyloader must be installed'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=310&site=drupal
# {'name': 'Valemount Lucaya M1208 - (requires activation)', 'cpu': 'ADM5120', 'ram': '32 MB', 'flash': '4 MB', 'additional_information': 'Compex WP54 v24 preSP2 buildMyloader must be installed'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=311&site=drupal
# {'name': 'Valemount Lucaya M1214 - (requires activation)', 'cpu': 'ADM5120', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'Compex WP54 v24 preSP2 buildMyloader must be installed'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=312&site=drupal
# {'name': 'Valemount Lucaya M1517 - (requires activation)', 'cpu': 'ADM5120', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'Compex WP54 v24 preSP2 buildMyloader must be installed'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=314&site=drupal
# {'name': 'Valemount Lucaya X4000 - (requires activation)', 'cpu': 'IXP425', 'ram': '64 MB', 'flash': '8 MB', 'additional_information': 'Compex WP54 v24 preSP2 buildMyloader must be installed'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=315&site=drupal
# {'name': 'Valemount Lucaya X4214 - (requires activation)', 'cpu': 'IXP425', 'ram': '64 MB', 'flash': '8 MB', 'additional_information': 'Compex WP54 v24 preSP2 buildMyloader must be installed'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=316&site=drupal
# {'name': 'Valemount Lucaya X4517 - (requires activation)', 'cpu': 'IXP425', 'ram': '64 MB', 'flash': '8 MB', 'additional_information': 'Compex WP54 v24 preSP2 buildMyloader must be installed'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=317&site=drupal
# {'name': 'Valemount WAR1-CPE - (requires activation)', 'cpu': 'ADM5120', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'Compex WP54 v24 preSP2 buildMyloader must be installed'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=318&site=drupal
# {'name': 'Valemount WAR2-MPW144B - (requires activation)', 'cpu': 'IXP420', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': 'Compex WP54 v24 preSP2 buildMyloader must be installed'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=187&site=drupal
# {'name': 'Valemount WAR4-MPW188B - (requires activation)', 'cpu': 'Xscale IXP425', 'ram': '64 MB', 'flash': '8 MB', 'additional_information': 'Compex WP54 v24 preSP2 buildMyloader must be installed'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=319&site=drupal
# {'name': 'Viewsonic WAPBR-100 -', 'cpu': '?', 'ram': '8 MB', 'flash': '2 MB', 'additional_information': '                 VXWorks needed ??                '}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=188&site=drupal
# {'name': 'Viewsonic WR100 -', 'cpu': 'Broadcom BCM4712 chip rev 1', 'ram': '8 MB', 'flash': '2 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=684&site=drupal
# {'name': 'Watchguard Firebox X1000 - (requires activation)', 'cpu': 'Socket 370 Celeron SL6C8 ', 'ram': '256 MB', 'flash': '64 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=189&site=drupal
# {'name': 'Watchguard FireboxII - (requires activation)', 'cpu': 'PentiumMMX', 'ram': '64 MB', 'flash': '8 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=191&site=drupal
# {'name': 'WiliGear WBD500 - (requires activation)', 'cpu': 'Atheros AR2315', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': 'Other downloads - http://dd-wrt.com/site/support/other-downloads?path=others%2Feko%2FBrainSlayer-V24-preSP2%2F'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=192&site=drupal
# {'name': 'Wistron CA8-4 Pro - (requires activation)', 'cpu': 'Atheros AR2313A', 'ram': '32 MB', 'flash': '4 MB', 'additional_information': 'Other downloads - http://dd-wrt.com/site/support/other-downloads?path=others%2Feko%2FBrainSlayer-V24-preSP2%2F'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=193&site=drupal
# {'name': 'Wistron RDAA-81 - (requires activation)', 'cpu': 'Atheros AR2313A', 'ram': '32 MB', 'flash': '4 MB', 'additional_information': 'Other downloads - http://dd-wrt.com/site/support/other-downloads?path=others%2Feko%2FBrainSlayer-V24-preSP2%2F'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=704&site=drupal
# {'name': 'Wistron RDAT-81 PCBA  - (requires activation)', 'cpu': 'AR5312', 'ram': '32 MB', 'flash': '4 MB', 'additional_information': 'Other downloads - http://dd-wrt.com/site/support/other-downloads?path=others%2Feko%2FBrainSlayer-V24-preSP2%2F'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=546&site=drupal
# {'name': 'X86 X86 \\ (requires activation)', 'cpu': 'x86', 'ram': '128 MB', 'flash': '64 MB', 'additional_information': 'DD-WRT Wiki: X86 - http://dd-wrt.com/wiki/index.php/X86'}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=882&site=drupal
# {'name': 'Yuncore XD3200 - (requires activation)', 'cpu': 'QCA9563', 'ram': '128 MB', 'flash': '16 MB', 'additional_information': ''}
# https://dd-wrt.com/routerdb/de/routerResult.php?action=routerDetail&id=479&site=drupal
# {'name': 'ZCOM TG2521 ? (requires activation)', 'cpu': 'ar9130', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': ''}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-979512867f13> in <module>()
#     213     for row in table_data:
#     214         if row:
# --> 215             writer.writerow(row)
#     216
#
# /usr/lib/python3.7/csv.py in writerow(self, rowdict)
#     153
#     154     def writerow(self, rowdict):
# --> 155         return self.writer.writerow(self._dict_to_list(rowdict))
#     156
#     157     def writerows(self, rowdicts):
#
# /usr/lib/python3.7/csv.py in _dict_to_list(self, rowdict)
#     149             if wrong_fields:
#     150                 raise ValueError("dict contains fields not in fieldnames: "
# --> 151                                  + ", ".join([repr(x) for x in wrong_fields]))
#     152         return (rowdict.get(key, self.restval) for key in self.fieldnames)
#     153
#
# ValueError: dict contains fields not in fieldnames: 'device_info'

# %%
new_strings = []
print(table_data)
for string in table_data:
  new_row = {}

  for ff, gg in string.items():
    #print("gg")
    #print(gg)
    new_row[ff] = str(gg).replace(r"\r", "")
  new_strings.append(new_row)

print(new_strings)
# Out:
# [{'Manufacturer': '8devices', 'Model': 'Lima', 'Revision': '-', 'Supported': 'yes', 'Activation required': 'yes', 'id': '886', 'device_info': {'name': '8devices Lima - (requires activation)', 'cpu': 'QCA4531', 'ram': '64 MB', 'flash': '32 MB', 'additional_information': ''}}, {'Manufacturer': '8devices', 'Model': 'Rambutan', 'Revision': '-', 'Supported': 'yes', 'Activation required': 'yes', 'id': '887', 'device_info': {'name': '8devices Rambutan - (requires activation)', 'cpu': 'QCA9557', 'ram': '128 MB', 'flash': '128 MB', 'additional_information': ''}}, {'Manufacturer': 'Abocom', 'Model': 'WAP2102', 'Revision': '-', 'Supported': 'yes', 'Activation required': 'yes', 'id': '385', 'device_info': {'name': 'Abocom WAP2102 - (requires activation)', 'cpu': 'AR2317', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'Same Hardware as : PlanexGW-MF54G2DD-WRT Forum: Flashing commands - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=411384#411384'}}, {'Manufacturer': 'Accton', 'Model': 'MR3201A', 'Revision': '-', 'Supported': 'yes', 'Activation required': 'yes', 'id': '1', 'device_info': {'name': 'Accton MR3201A - (requires activation)', 'cpu': 'Atheros AR531X', 'ram': '16 MB', 'flash': '8 MB', 'additional_information': 'DD-WRT Wiki: Accton Software FlashingDD-WRT Wiki: Reflash Stock Firmware - http://www.dd-wrt.com/wiki/index.php/Accton_Software_Flashing - https://wiki.dd-wrt.com/wiki/index.php/Accton_Software_Flashing#Reflashing_Accton_original_firmware'}}, {'Manufacturer': 'Accton', 'Model': 'MR3202a', 'Revision': '-', 'Supported': 'yes', 'Activation required': 'yes', 'id': '2', 'device_info': {'name': 'Accton MR3202a - (requires activation)', 'cpu': 'Atheros', 'ram': '0 MB', 'flash': '0 MB', 'additional_information': 'DD-WRT Wiki: Accton Software FlashingDD-WRT Wiki: Reflash Stock Firmware - http://www.dd-wrt.com/wiki/index.php/Accton_Software_Flashing - https://wiki.dd-wrt.com/wiki/index.php/Accton_Software_Flashing#Reflashing_Accton_original_firmware'}}, {'Manufacturer': 'Aceex', 'Model': 'NR22/Y', 'Revision': '', 'Supported': 'yes', 'Activation required': 'no', 'id': '394', 'device_info': {'name': 'Aceex NR22/Y  ', 'cpu': 'RT3052F', 'ram': '32 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Forum: Flashing instructionsDD-WRT Forum: Reflash stock firmware - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=364500#364500 - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=364724#364724'}}, {'Manufacturer': 'Actiontec', 'Model': 'MI424WR', 'Revision': 'A, B', 'Supported': 'yes', 'Activation required': 'no', 'id': '324', 'device_info': {'name': 'Actiontec MI424WR A, B', 'cpu': 'IXP425', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': "OEM'd to Verizon, FIOS port will not work!DD-WRT Wiki: MI424WRDD-WRT Forum: Revert stock firmware - http://dd-wrt.com/wiki/index.php/MI424WR - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=631396#631396"}}, {'Manufacturer': 'Actiontec', 'Model': 'MI424WR', 'Revision': 'C', 'Supported': 'yes', 'Activation required': 'no', 'id': '402', 'device_info': {'name': 'Actiontec MI424WR C', 'cpu': 'IXP425', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': "OEM'd to Verizon, FIOS port will not work! DD-WRT Wiki: MI424WRDD-WRT Forum: Revert stock firmware - http://dd-wrt.com/wiki/index.php/MI424WR - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=631396#631396"}}, {'Manufacturer': 'Actiontec', 'Model': 'MI424WR', 'Revision': 'D', 'Supported': 'yes', 'Activation required': 'no', 'id': '375', 'device_info': {'name': 'Actiontec MI424WR D', 'cpu': 'IXP425', 'ram': '32 MB', 'flash': '8 MB', 'additional_information': "OEM'd to Verizon, FIOS port will not work! DD-WRT Wiki: MI424WRDD-WRT Forum: Revert stock firmware - http://dd-wrt.com/wiki/index.php/MI424WR - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=631396#631396"}}, {'Manufacturer': 'ADI Engineering', 'Model': 'Pronghorn Metro SBC', 'Revision': '-', 'Supported': 'yes', 'Activation required': 'yes', 'id': '3', 'device_info': {'name': 'ADI Enginee ...
# [{'Manufacturer': '8devices', 'Model': 'Lima', 'Revision': '-', 'Supported': 'yes', 'Activation required': 'yes', 'id': '886', 'device_info': "{'name': '8devices Lima - (requires activation)', 'cpu': 'QCA4531', 'ram': '64 MB', 'flash': '32 MB', 'additional_information': ''}"}, {'Manufacturer': '8devices', 'Model': 'Rambutan', 'Revision': '-', 'Supported': 'yes', 'Activation required': 'yes', 'id': '887', 'device_info': "{'name': '8devices Rambutan - (requires activation)', 'cpu': 'QCA9557', 'ram': '128 MB', 'flash': '128 MB', 'additional_information': ''}"}, {'Manufacturer': 'Abocom', 'Model': 'WAP2102', 'Revision': '-', 'Supported': 'yes', 'Activation required': 'yes', 'id': '385', 'device_info': "{'name': 'Abocom WAP2102 - (requires activation)', 'cpu': 'AR2317', 'ram': '16 MB', 'flash': '4 MB', 'additional_information': 'Same Hardware as : PlanexGW-MF54G2DD-WRT Forum: Flashing commands - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=411384#411384'}"}, {'Manufacturer': 'Accton', 'Model': 'MR3201A', 'Revision': '-', 'Supported': 'yes', 'Activation required': 'yes', 'id': '1', 'device_info': "{'name': 'Accton MR3201A - (requires activation)', 'cpu': 'Atheros AR531X', 'ram': '16 MB', 'flash': '8 MB', 'additional_information': 'DD-WRT Wiki: Accton Software FlashingDD-WRT Wiki: Reflash Stock Firmware - http://www.dd-wrt.com/wiki/index.php/Accton_Software_Flashing - https://wiki.dd-wrt.com/wiki/index.php/Accton_Software_Flashing#Reflashing_Accton_original_firmware'}"}, {'Manufacturer': 'Accton', 'Model': 'MR3202a', 'Revision': '-', 'Supported': 'yes', 'Activation required': 'yes', 'id': '2', 'device_info': "{'name': 'Accton MR3202a - (requires activation)', 'cpu': 'Atheros', 'ram': '0 MB', 'flash': '0 MB', 'additional_information': 'DD-WRT Wiki: Accton Software FlashingDD-WRT Wiki: Reflash Stock Firmware - http://www.dd-wrt.com/wiki/index.php/Accton_Software_Flashing - https://wiki.dd-wrt.com/wiki/index.php/Accton_Software_Flashing#Reflashing_Accton_original_firmware'}"}, {'Manufacturer': 'Aceex', 'Model': 'NR22/Y', 'Revision': '', 'Supported': 'yes', 'Activation required': 'no', 'id': '394', 'device_info': "{'name': 'Aceex NR22/Y  ', 'cpu': 'RT3052F', 'ram': '32 MB', 'flash': '4 MB', 'additional_information': 'DD-WRT Forum: Flashing instructionsDD-WRT Forum: Reflash stock firmware - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=364500#364500 - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=364724#364724'}"}, {'Manufacturer': 'Actiontec', 'Model': 'MI424WR', 'Revision': 'A, B', 'Supported': 'yes', 'Activation required': 'no', 'id': '324', 'device_info': '{\'name\': \'Actiontec MI424WR A, B\', \'cpu\': \'IXP425\', \'ram\': \'32 MB\', \'flash\': \'8 MB\', \'additional_information\': "OEM\'d to Verizon, FIOS port will not work!DD-WRT Wiki: MI424WRDD-WRT Forum: Revert stock firmware - http://dd-wrt.com/wiki/index.php/MI424WR - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=631396#631396"}'}, {'Manufacturer': 'Actiontec', 'Model': 'MI424WR', 'Revision': 'C', 'Supported': 'yes', 'Activation required': 'no', 'id': '402', 'device_info': '{\'name\': \'Actiontec MI424WR C\', \'cpu\': \'IXP425\', \'ram\': \'32 MB\', \'flash\': \'8 MB\', \'additional_information\': "OEM\'d to Verizon, FIOS port will not work! DD-WRT Wiki: MI424WRDD-WRT Forum: Revert stock firmware - http://dd-wrt.com/wiki/index.php/MI424WR - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=631396#631396"}'}, {'Manufacturer': 'Actiontec', 'Model': 'MI424WR', 'Revision': 'D', 'Supported': 'yes', 'Activation required': 'no', 'id': '375', 'device_info': '{\'name\': \'Actiontec MI424WR D\', \'cpu\': \'IXP425\', \'ram\': \'32 MB\', \'flash\': \'8 MB\', \'additional_information\': "OEM\'d to Verizon, FIOS port will not work! DD-WRT Wiki: MI424WRDD-WRT Forum: Revert stock firmware - http://dd-wrt.com/wiki/index.php/MI424WR - http://www.dd-wrt.com/phpBB2/viewtopic.php?p=631396#631396"}'}, {'Manufacturer': 'ADI Engineering', 'Model': 'Pronghorn Metro SBC', 'Revision': '-', 'Supported': 'yes', 'A ...

# %%
#print(t_headers)
#print(table_data)
import pandas as pd

datos = pd.DataFrame(new_strings)
datos = datos.convert_dtypes(infer_objects=False) 
agg = datos.copy(deep=False)
#agg = agg.reset_index()
final = None
for y in agg.columns:
    print(agg[y].dtype)
    
    if(agg[y].dtype == object or type(agg[y]) == object):
        print("is obj")
        print(agg[y][0])

        #agg[y].tolist()
        # https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.explode.html
        print(agg[y].name)
        #agg = agg.explode(agg[y].name)
        #agg = pd.json_normalize(agg[agg[y].name])
        aggclone = agg.copy(deep=False)
        #print(agg[y].name)
        #aggclone = aggclone.drop(aggclone[y].name, axis=1)

        
        agg = agg.join(pd.json_normalize(agg[y]))


        #aggclone = agg.copy(deep=False)
        #print(agg[y].name)
        #aggclone = aggclone.drop(aggclone[y].name, axis=1)
    else:
        "do nothing" 
agg.dtypes
#datos.head
agg.to_csv('test1.csv', index=False, encoding='utf-8')

agg.columns
# Out:
# string
# string
# string
# string
# string
# string
# string
# Index(['Manufacturer', 'Model', 'Revision', 'Supported', 'Activation required',
#        'id', 'device_info'],
#       dtype='object')
